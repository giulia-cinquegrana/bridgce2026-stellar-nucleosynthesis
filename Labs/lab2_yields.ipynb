# %%
# Given a set of yields, compute the population weighted yields. 

# LIMS yields = 1-8Msun
# SNe yields = X to XMsun

# at solar metallicity:

# 1. what contribution of Mg comes from AGBs vs Type II SNe? 
# 2. what about at the isotope level for Mg?
# 3. how much of the first s process peak comes from AGBs vs Type II SNe?
# 4. how much of the third s process peak comes from AGBs vs Type II SNe?
# 5. what about isotopes of Ba. s-process vs i-process?

# at low metallicity:
